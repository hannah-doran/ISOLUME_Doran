# %%
import sys
import geopandas as gpd
import pandas as pd

# Check if the modules import correctly
print(f"Python executable: {sys.executable}")
print(f"Geopandas version: {gpd.__version__}")

# Create a tiny test object to ensure memory/geometry is working
test_df = gpd.GeoDataFrame({'val': [1]}, geometry=[gpd.points_from_xy([0], [0])[0]], crs="EPSG:4326")
print("Test successful: GeoDataFrame created.")

# Test a projection (this ensures your projection libraries are working)
test_3035 = test_df.to_crs(epsg=3035)
print("Test successful: Projection to EPSG:3035 worked.")
